# %%
# -*- coding: utf-8 -*-
"""Untitled8.ipynb
Automatically generated by Colaboratory.
Original file is located at
    https://colab.research.google.com/drive/1cmZqPMJSkAO3VlPItN5L-AgUNfPe1o22
"""

# -*- coding: utf-8 -*-
"""Untitled18.ipynb
Automatically generated by Colaboratory.
Original file is located at
    https://colab.research.google.com/drive/1ANoV7AhqUPwgpLl_aIF-6euL39uLdxmy
"""

import numpy as np
import matplotlib.pyplot as plt
import numpy.linalg as LA

#inputs
n1 = np.array([1,1])
c1 = 4
n2 = np.array([3,-1])
c2 = 0

plt.axis([-4,6,-4,6])
plt.text(0,0,'PQ(0,0)')
plt.text(4,0,'A(4,0)')
plt.text(0,4,'B(0,4)')
plt.axis('on')
plt.grid()#minor
plt.plot([4,0],[0,4])
plt.plot([0,0],[0,0])
plt.show()
